# %%
import csv

with open('NFT_Top_Collections.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    
    for line in  csv_reader:
        print(line[:5])
# Out:
# ['Index', 'Name', 'Volume', 'Volume_USD', 'Market_Cap']
# ['0', 'basis.markets', '27256.63', '4001818.417', '708.1454545']
# ['1', 'Skeleton Crew Skulls', '11381.25', '1670995.125', '106.656']
# ['2', 'Flippies', '6732.19', '988420.1358', '1663.863158']
# ['3', 'Meerkat Millionaires Country Club', '3734.76', '548337.4632', '90.275']
# ['4', 'Stylish Studs', '3191.15', '468524.643', '165']
# ['5', "I'M AIKO", '2904.7', '426468.054', '2530.877143']
# ['6', 'Crypto Idolz', '2315.74', '339996.9468', '1168.041981']
# ['7', 'Megalodon Rogue Shark Tooth', '2116.61', '310760.6802', '60.050375']
# ['8', 'CorruptCatz', '1983.92', '291279.1344', '345.79']
# ['9', 'Meta Waifus', '1844.59', '270822.7038', '989.4912667']
# ['10', 'Crypto Idolz - Butts', '1756.29', '257858.4978', '910.915461']
# ['11', 'Doge Capital', '1630.23', '239350.3686', '5.62']
# ['12', 'Hot Bunnies NFT', '1590.89', '233574.4698', '527.85']
# ['13', 'BOSS BULLS â„¢ CLUB', '1236.33', '181517.9706', '244.6866667']
# ...

# %%
import pandas as pd

df = pd.read_csv('NFT_Top_Collections.csv')

print(df.head(3))
# Out:
#    Index                  Name    Volume    Volume_USD   Market_Cap  \
# 0      0         basis.markets  27256.63  4.001818e+06   708.145455
# 1      1  Skeleton Crew Skulls  11381.25  1.670995e+06   106.656000
# 2      2              Flippies   6732.19  9.884201e+05  1663.863158
#
#    Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  Average_Price  \
# 0    103969.91560    366        39.50        5799.3900      74.471667
# 1     15659.23392   2075         0.67          98.3694       5.484940
# 2    244288.38880   1504         0.80         117.4560       4.476190
#
#    Average_Price_USD  Owners  Assets  Owner_Asset_Ratio  \
# 0       10933.930100      12      16              75.00
# 1         805.298855     103     132              78.03
# 2         657.194239     905    1638              55.25
#
#                          Category                    Website  \
# 0  Collectibles,Digital,Privilege     https://basis.markets/
# ...

# %%
# read headers
print(df.columns)
# Out:
# Index(['Index', 'Name', 'Volume', 'Volume_USD', 'Market_Cap', 'Market_Cap_USD',
#        'Sales', 'Floor_Price', 'Floor_Price_USD', 'Average_Price',
#        'Average_Price_USD', 'Owners', 'Assets', 'Owner_Asset_Ratio',
#        'Category', 'Website', 'Logo'],
#       dtype='object')

# %%
# read each column
print(df[['Name', 'Owner_Asset_Ratio']])
# Out:
#                                   Name  Owner_Asset_Ratio
# 0                        basis.markets              75.00
# 1                 Skeleton Crew Skulls              78.03
# 2                             Flippies              55.25
# 3    Meerkat Millionaires Country Club              82.61
# 4                        Stylish Studs              56.00
# ..                                 ...                ...
# 587                NEO MONKEY BUSINESS              50.00
# 588                          Cops Game             100.00
# 589                   Floppa Syndicate                NaN
# 590                           Duck BRO              67.86
# 591                         CryptoPets              69.57
#
# [592 rows x 2 columns]

# %%
df.sort_values(['Category'], ascending=True)
# Out:
#      Index                    Name  Volume  Volume_USD  Market_Cap  \
# 476    477          NFT Mint Watch    6.04    886.7928      35.520
# 589    597        Floppa Syndicate    0.00      0.0000       0.000
# 155    155        Multiverse Llama   72.48  10641.5136      41.400
# 467    468         SolKitty Family    6.41    941.1162       3.630
# 68      68  Billionaire Whale Club  243.31  35722.7742      56.025
# ..     ...                     ...     ...         ...         ...
# 585    593           EgoClash 2021    0.00      0.0000       0.000
# 586    594           Powder Heroes    0.00      0.0000       0.000
# 587    595     NEO MONKEY BUSINESS    0.00      0.0000       0.000
# 588    596               Cops Game    0.00      0.0000       0.000
# 591    599              CryptoPets    0.00      0.0000       0.000
#
#      Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  Average_Price  \
# 476       5215.0464     52         0.10          14.6820       0.116154
# ...

# %%
new_df = df.loc[(df['Volume'] > 6.41) & (df['Sales'] > 1000) & (df['Owner_Asset_Ratio'] < 50)]

# %%
new_df
# Out:
#      Index                  Name   Volume   Volume_USD   Market_Cap  \
# 5        5              I'M AIKO  2904.70  426468.0540  2530.877143
# 6        6          Crypto Idolz  2315.74  339996.9468  1168.041981
# 10      10  Crypto Idolz - Butts  1756.29  257858.4978   910.915461
# 15      15  Crypto Idolz - Faces   990.64  145445.7648   962.156774
# 80      80     Gangster Gorillas   206.79   30360.9078   119.102299
# 89      89             Popsicle    177.73   26094.3186   167.271562
# 135    135          Gapes on Sol    91.10   13375.3020    42.570000
#
#      Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  Average_Price  \
# 5      371583.38210   1411         1.20         176.1840       2.058611
# 6      171491.92370   1418         0.60          88.0920       1.633103
# 10     133740.60800   2906         0.24          35.2368       0.604367
# 15     141263.85760   1264         0.25          36.7050       0.783734
# ...

# %%
df.loc[df['Name'].str.contains('Sol')]
# Out:
#      Index                  Name   Volume   Volume_USD  Market_Cap  \
# 14      14    Solana Doodle Apes  1132.74  166308.8868  327.888889
# 18      18             Solchicks   858.32  126018.5424    0.000000
# 22      22              Solagon    718.88  105545.9616   68.000000
# 25      25  SolanaMonkeyBusiness   695.00  102039.9000    0.000000
# 26      26           Sol Snipers   668.68   98175.5976    0.000000
# ..     ...                   ...      ...          ...         ...
# 568    574   Solana MutantPunks      2.75     403.7550    0.000000
# 572    578    Solana Koala - RUG     2.20     323.0040   47.933333
# 581    587             SolNFTPad     0.60      88.0920  123.000000
# 582    588                 Solez     0.10      14.6820    1.300000
# 583    591        Solana Piranha     0.00       0.0000    0.000000
#
#      Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  Average_Price  \
# 14      48140.64667   1162         1.50         220.2300       0.974819
# ...

# %%
df.groupby(['Assets']).mean().sort_values('Volume', ascending=False)
# Out:
#         Index     Volume    Volume_USD   Market_Cap  Market_Cap_USD   Sales  \
# Assets
# 16      219.0  6846.1575  1.005153e+06   182.505837    26795.507026   110.0
# 1638      2.0  6732.1900  9.884201e+05  1663.863158   244288.388800  1504.0
# 132     251.5  5693.3400  8.358962e+05    53.328000     7829.616960  1041.5
# 1206      5.0  2904.7000  4.264681e+05  2530.877143   371583.382100  1411.0
# 529       6.0  2315.7400  3.399969e+05  1168.041981   171491.923700  1418.0
# ...       ...        ...           ...          ...             ...     ...
# 264     563.0     3.7200  5.461704e+02    44.640000     6554.044800    22.0
# 81      574.0     2.7500  4.037550e+02     0.000000        0.000000    87.0
# 719     578.0     2.2000  3.230040e+02    47.933333     7037.572000    33.0
# 205     587.0     0.6000  8.809200e+01   123.000000    18058.860000     1.0
# 392     593.0     0.0000  0.000000e+00     0.000000        0.000000     0.0
#
# ...

# %%
df.groupby(['Owner_Asset_Ratio']).count()
# Out:
#                    Index  Name  Volume  Volume_USD  Market_Cap  \
# Owner_Asset_Ratio
# 0.26                   1     1       1           1           1
# 0.62                   1     1       1           1           1
# 0.76                   1     1       1           1           1
# 0.94                   1     1       1           1           1
# 1.11                   1     1       1           1           1
# ...                  ...   ...     ...         ...         ...
# 92.96                  1     1       1           1           1
# 93.33                  4     4       4           4           4
# 93.75                  1     1       1           1           1
# 94.12                  1     1       1           1           1
# 100.00                47    47      47          47          47
#
#                    Market_Cap_USD  Sales  Floor_Price  Floor_Price_USD  \
# Owner_Asset_Ratio
# 0.26                            1      1            1                1
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3]
y = [2,4,6]

#long plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', markersize=10)
#short
#plt.plot(x,y, 'r.--', label='2x')

x2 = np.arange(0,4.5,0.5)
plt.plot(x2[:5], x2[:5]**2, 'r', label='x^2')
plt.plot(x2[4:], x2[4:]**2, 'r--')
plt.title('First Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.xticks([0,5,10,15,20])
plt.yticks([0,5,10,15,20])

plt.legend()

plt.savefig('mygraph.png', dpi=100)

plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,2,4]

plt.bar(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\Aaron\\Downloads\\archive',
#  'C:\\Users\\Aaron\\anaconda3\\python38.zip',
#  'C:\\Users\\Aaron\\anaconda3\\DLLs',
#  'C:\\Users\\Aaron\\anaconda3\\lib',
#  'C:\\Users\\Aaron\\anaconda3',
#  '',
#  'C:\\Users\\Aaron\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\Aaron\\anaconda3\\lib\\site-packages\\locket-0.2.1-py3.8.egg',
#  'C:\\Users\\Aaron\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Aaron\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Aaron\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Aaron\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Aaron\\.ipython']

# %%
a = np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
b = np.array([[9.0,8.5,7.2],[3.5,3.3,6.0]])
b
# Out:
# array([[9. , 8.5, 7.2],
#        [3.5, 3.3, 6. ]])

# %%
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2
